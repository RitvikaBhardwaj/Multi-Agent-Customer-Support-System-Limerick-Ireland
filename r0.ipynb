# %% [markdown]
# <a href="https://colab.research.google.com/github/RitvikaBhardwaj/Multi-Agent-Customer-Support-System-Limerick-Ireland/blob/main/r0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# x <- c(1,2,3,4)
# mean(x)
# Out:
# [1] 2.5

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# x <- c(1,2,3,4,5)
# mean(x)
# Out:
# [1] 3
